# %%
import pandas as pd
import numpy as np
import re
import os
import matplotlib as mpl
import json

from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %%
def count_list_of_list(list_of_lists):
    """
    Input: List of list of keywords
    Output: {keyword: count} dict
    """
    counter = Counter()

    # Allowed characters: letters, digits, spaces, and selected punctuation
    allowed_pattern = r"[a-z0-9\s\-/.,&'():]+"

    for sublist in list_of_lists:
        cleaned_items = set()
        for word in sublist:
            if not isinstance(word, str):
                continue
            w = word.strip().lower()

            if re.fullmatch(allowed_pattern, w):
                cleaned_items.add(w)

        counter.update(cleaned_items)

    return dict(counter)

def count_list(words):

    cleaned = [
        w.lower()
        for w in words
        if isinstance(w, str) and len(w.strip()) >= 1
    ]
    
    # Count the terms
    return dict(Counter(cleaned))

def count_unique_keywords(keywords):
    if not keywords:
        return {}

    # Case 1: List[str]
    if isinstance(keywords[0], str):
        return count_list(keywords)

    # Case 2: List[List[str]]
    if isinstance(keywords[0], (list, np.ndarray)):
        return count_list_of_list(keywords)

    # Otherwise raise error
    raise TypeError(
        f"Invalid keywords type: expected List[str] or List[List[str]], "
        f"got element of type {type(keywords[0])}"
    )


def counter_to_df(word_counts, store_name):
    df = pd.DataFrame(word_counts.items(), columns=['keyword', 'count'])
    df = df.sort_values(by='count', ascending=False, ignore_index=True)
    df['store_name'] = store_name
    return df

def item_list_to_df(store_keywords, store_name):
    word_count_dict = count_unique_keywords(store_keywords)
    res = counter_to_df(word_count_dict, store_name)
    return res
    
def join_keywords_in_list(list_of_lists, special_color="green", max_words=3):
    result = []
    for colors in list_of_lists:
        # Always include special_color if present
        has_special = special_color in colors

        # Take first max_words items, but ensure special_color is kept
        subset = colors[:max_words]
        if has_special and special_color not in subset:
            # Replace last element with special_color (preserve max length)
            if len(subset) == max_words:
                subset[-1] = special_color
            else:
                subset.append(special_color)

        # ✅ Only ensure special_color comes first, preserve original order otherwise
        subset = list(subset)
        subset.sort(key=lambda c: (c != special_color, c))

        # Join and wrap in list
        result.append([" ".join(subset)])
    return result


""" Add param to allow for combining of keywords """
def keyword_count_store_key_df(df, key, store_name, join_keywords = False):
    # Get [['cypress', 'fir'], ['magnolia']] 
    store_df = df[df.store_name == store_name]
    store_keywords =  store_df[key].values.tolist()

    # if flatten: store_keywords = ...
    if join_keywords:
        store_keywords = join_keywords_in_list(store_keywords)

    res = item_list_to_df(store_keywords, store_name)
    return res

# %%
def minmax_scale(data):
    """
    Scales a list or numpy array of numbers to the range [0, 100].
    Handles edge cases like constant values safely.
    """
    arr = np.array(data, dtype=float)
    min_val, max_val = np.min(arr), np.max(arr)

    # Avoid division by zero if all values are equal
    if min_val == max_val:
        return np.zeros_like(arr)

    scaled = (arr - min_val) / (max_val - min_val) * 100
    return scaled

def pivot_keyword_dfs(dfs: list[pd.DataFrame]) -> pd.DataFrame:
        
    if not dfs:
        return pd.DataFrame()

    # Combine all DataFrames
    merged_df = pd.concat(dfs, ignore_index=True)

    # Pivot table: keywords as rows, store_names as columns
    pivot_df = merged_df.pivot_table(
        index='keyword',
        columns='store_name',
        values='count',
        aggfunc='sum',  # if duplicates exist, sum counts
        fill_value=0
    )
    
    return pivot_df

def get_pct_stores(df: pd.DataFrame) -> pd.DataFrame:
    """
    Adds a 'pct_stores' column showing the fraction of stores
    (columns) where the keyword has a count > 0. 
    Then sorts by pct_stores descending, then by row sum of counts descending.
    """
    pivot_df = df.copy()
    store_count = pivot_df.shape[1]
    
    # Compute pct_stores
    pivot_df['pct_stores'] = (pivot_df.gt(0).sum(axis=1) / store_count).round(2)
    
    # Compute row sum across numeric columns excluding pct_stores
    numeric_cols = pivot_df.select_dtypes(include='number').columns.tolist()
    sum_cols = [col for col in numeric_cols if col != 'pct_stores']
    
    item_totals = pivot_df[sum_cols].sum(axis=1).values
    pivot_df['score'] = minmax_scale(item_totals)/100
    
    # Sort first by pct_stores, then by row sum
    pivot_df = pivot_df.sort_values(by=['score', 'pct_stores'], ascending=False)
    pivot_df = pivot_df[[c for c in pivot_df.columns if c != 'pct_stores'] + ['pct_stores']]
    
    return pivot_df

# %%
def divide_df_by_store_sizes(df, store_sizes):
    print(df.columns)
    if len(df.columns) != len(store_sizes):
        raise ValueError("❌ Length of store_sizes must match number of DataFrame columns.")
    
    # Convert to Series for broadcasting
    divisors = pd.Series(store_sizes, index=df.columns)
    return df.divide(divisors, axis='columns')

def normalize_store_columns(df: pd.DataFrame) -> pd.DataFrame:
    # Exclude non-numeric columns like 'pct_stores' if present
    numeric_df = df.select_dtypes(include='number')

    # Compute column-wise percentages
    pct_df = numeric_df.div(numeric_df.sum(axis=0), axis=1).round(2)

    # Retain non-numeric columns if any
    non_numeric = df.drop(columns=numeric_df.columns, errors='ignore')
    result = pd.concat([pct_df, non_numeric], axis=1)

    return result

def normalize_pivot_df(df, store_sizes, how = "store_size"):
    # print(df)
    if how == "store_size":
        return divide_df_by_store_sizes(df, store_sizes)
    else:
        return normalize_store_columns(df)

def generate_pivots(dfs, store_sizes, store_names = None, how = "store_size"):
    pivot_df = pivot_keyword_dfs(dfs)
    pivot_df = pivot_df[store_names]

    # EITHER BY STORE SIZE OF NORMALIZE
    pivot_df_pcts = normalize_pivot_df(pivot_df, store_sizes, how = how)

    pivot_df = pivot_df[store_names]
    pivot_df_pcts = pivot_df_pcts[store_names]
    
    return pivot_df, pivot_df_pcts

def aggregate_count_dfs(dfs, store_sizes, store_names = None, how = "store_size"):
    pivot_df, pivot_df_pcts = generate_pivots(dfs, store_sizes, store_names, how)
    # print(pivot_df)
    # MAKE SURE STORE COLUMNS MATCH

    count_df = get_pct_stores(pivot_df)
    pct_df = get_pct_stores(pivot_df_pcts)

    count_df = count_df[count_df.pct_stores > 0]
    pct_df = pct_df[pct_df.pct_stores > 0]

    return count_df, pct_df

def colorize_df(df: pd.DataFrame, base_cmap: str = "Greens", min_frac: float = 0.0, max_frac: float = 0.6):
    # Get original colormap
    cmap_orig = mpl.cm.get_cmap(base_cmap)
    
    # Slice colormap to soften extremes
    cmap_vals = cmap_orig(np.linspace(min_frac, max_frac, 256))
    # Remove alpha channel for pandas
    cmap_vals = cmap_vals[:, :-1]
    soft_cmap = mpl.colors.ListedColormap(cmap_vals)

    return (
        df.style
        .background_gradient(cmap=soft_cmap, vmin=0, vmax=100, axis=None)
        .format("{:.0f}%")
    )

def generate_color_map(dfs, store_sizes, store_names, how = "store_size"):
    count_pivot, pct_pivot = aggregate_count_dfs(dfs, store_sizes, store_names, how)
    return count_pivot, pct_pivot, colorize_df(pct_pivot*100)

# %%
def df_to_colortable(df, key, how = 'store_size', join_keywords = False):
    # Get df of keyword counts for each store
    store_names = df.store_name.unique()
    keyword_count_dfs = [keyword_count_store_key_df(df, key, store, join_keywords) for store in store_names]
    store_sizes = [len(df[df.store_name == store]) for store in store_names]
    print("store_sizes", store_sizes)

    # Pivot
    counts, pcts, color_table = generate_color_map(keyword_count_dfs, store_sizes, store_names, how)
    return counts, pcts, color_table

# %% [markdown]
# ### Try!

# %% [markdown]
# ##### Load df

# %%
df = pd.read_parquet("final_flower_america_df.parquet")

# %%
df[df['flower_type'].apply(lambda x: len(x) > 1)]
# Out:
#                                                    Name  \
# 83    Faux-Ever Large Cream White Fake Rose and Peon...
# 179   Pink Cream Fake Peony and Eucalyptus Flower Bo...
# 347                            Coral Garden Arrangement
# 348                          Southern Charm Arrangement
# 349                 Outdoor Vivid Blooms Hanging Basket
# ...                                                 ...
# 3474                   Mix Floral in Rectangle Vase 16"
# 3476                 Caf au Lait Combo in Vase 25" wide
# 3478                     Mix Floral in Square Vase 9.5"
# 3484                       Tulip & Peony in Cylinder 9"
# 3508        Hydrangea & Snowball in Clear Vase 15" Wide
#
#                                             Description    Price   store_name  \
# 83    Make your wedding day stress-free when you cho...  $120.00       Aflora
# 179   Embrace the versatility of premade artificial ...   $36.00       Aflora
# 347   Elevate your home dcor with vibrant blooms. Sh...     $299  Balsam Hill
# 348   Bring warmth and elegance to your home with th...     $299  Balsam Hill
# 349   Refresh your homes exterior with the Outdoor V...     $229  Balsam Hill
# ...                                                 ...      ...          ...
# 3474  Subscribe to our newsletters to receive 10% of...  $580.00      Winward
# 3476  Subscribe to our newsletters to receive 10% of...  $930.00      Winward
# 3478  Subscribe to our newsletters to receive 10% of...  $800.00      Winward
# 3484  Subscribe to our newsletters to receive 10% of...  $500.00      Winward
# 3508  Subscribe to our newsletters to receive 10% of...  $720.00      Winward
#
#                Store Type Store Quality  \
# 83    Independent Website             A
# 179   Independent Website             A
# 347   Independent Website             A
# 348   Independent Website             A
# 349   Independent Website             A
# ...                   ...           ...
# 3474  Independent Website             A
# 3476  Independent Website             A
# 3478  Independent Website             A
# 3484  Independent Website             A
# 3508  Independent Website             A
#
#                                  Product Type  \
# 83                     All Artificial Flowers
# 179                    All Artificial Flowers
# 347   Spring Artificial Flowers & Floral Dcor
# 348   Spring Artificial Flowers & Floral Dcor
# 349   Spring Artificial Flowers & Floral Dcor
# ...                                       ...
# 3474       Luxurious Faux Flower Arrangements
# 3476       Luxurious Faux Flower Arrangements
# 3478       Luxurious Faux Flower Arrangements
# 3484       Luxurious Faux Flower Arrangements
# 3508       Luxurious Faux Flower Arrangements
#
#                                            Product Link  \
# 83    https://www.afloral.com/collections/artificial...
# 179   https://www.afloral.com/collections/artificial...
# 347   https://www.balsamhill.com/f/coral-garden-flor...
# 348   https://www.balsamhill.com/f/southern-charm-fl...
# 349   https://www.balsamhill.com/f/outdoor-vivid-blo...
# ...                                                 ...
# 3474  https://www.winwardhome.com/products/mix-flora...
# 3476  https://www.winwardhome.com/products/cafe-au-l...
# 3478  https://www.winwardhome.com/products/mix-flora...
# 3484  https://www.winwardhome.com/products/tulip-peo...
# 3508  https://www.winwardhome.com/products/hydrangea...
#
#                                           Main Img Link   filename plant_type  \
# 83    https://www.afloral.com/cdn/shop/files/PDP_58_...   Image_84     flower
# 179   https://www.afloral.com/cdn/shop/files/Afloral...  Image_180     flower
# 347   https://source.widen.net/content/zumk7pwyqz/we...    Image_3     flower
# 348   https://source.widen.net/content/4uvhazrjlf/we...    Image_4     flower
# 349   https://source.widen.net/content/uba1nbhgfg/we...    Image_5     flower
# ...                                                 ...        ...        ...
# 3474  https://www.winwardhome.com/cdn/shop/files/WHD...  Image_302     flower
# 3476  https://www.winwardhome.com/cdn/shop/files/WHD...  Image_304     flower
# 3478  https://www.winwardhome.com/cdn/shop/files/WHD...  Image_306     flower
# 3484  https://www.winwardhome.com/cdn/shop/files/SDP...  Image_312     flower
# 3508  https://www.winwardhome.com/cdn/shop/products/...  Image_336     flower
#
#                                          flower_type  \
# 83                                     [peony, rose]
# 179                               [peony, hydrangea]
# 347           [peony, dahlia, hydrangea, ranunculus]
# 348                                [rose, hydrangea]
# 349   [ranunculus, zinnia, dahlia, daisy, hydrangea]
# ...                                              ...
# 3474                       [peony, rose, snapdragon]
# 3476                           [peony, rose, dahlia]
# 3478                   [rose, hydrangea, helleborus]
# 3484                      [peony, zinnia, hydrangea]
# 3508                               [rose, hydrangea]
#
#                                  flower_colors     leaf_type product_type  \
# 83                                     [white]            []  single stem
# 179                         [pink, red, white]  [eucalyptus]  single stem
# 347                     [green, orange, peach]            []  arrangement
# 348                                    [white]            []  arrangement
# 349   [cream, green, pink, red, white, yellow]         [ivy]  arrangement
# ...                                        ...           ...          ...
# 3474                     [cream, peach, white]            []  arrangement
# 3476                             [pink, white]            []  arrangement
# 3478                      [cream, green, pink]            []  arrangement
# 3484                     [green, pink, yellow]            []  arrangement
# 3508                                   [white]            []  arrangement
#
#      container  how_many_flowers  \
# 83        none                 2
# 179       none                 2
# 347       vase                 4
# 348        pot                 2
# 349    planter                 5
# ...        ...               ...
# 3474      vase                 3
# 3476      vase                 3
# 3478      vase                 3
# 3484      vase                 3
# 3508      vase                 2
#
#                                         name_normalized        flowers_in_name
# 83    faux-ever large cream white fake rose and peon...          [peony, rose]
# 179   pink cream fake peony and eucalyptus flower bo...    [eucalyptus, peony]
# 347                            coral garden arrangement                     []
# 348                          southern charm arrangement                     []
# 349                  outdoor vivid bloom hanging basket                     []
# ...                                                 ...                    ...
# 3474                 mix floral in rectangle vase 16 ''                     []
# 3476               caf au lait combo in vase 25 '' wide                     []
# 3478                   mix floral in square vase 9.5 ''                     []
# 3484                     tulip & peony in cylinder 9 ''         [peony, tulip]
# 3508      hydrangea & snowball in clear vase 15 '' wide  [hydrangea, snowball]
#
# [515 rows x 19 columns]

# %%
df.plant_type.value_counts()
# Out:
# plant_type
# flower    3032
# leaves     345
# berry       92
#             42
# Name: count, dtype: int64

# %%
df[df.plant_type == 'leaves']['Main Img Link'].values.tolist()
# Out:
# ['https://www.afloral.com/cdn/shop/files/AA-N1-053_df023216-f416-436b-b840-b128c0533705.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124354025/string-of-pearls-in-white-oak-pot-5.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124329393/eucalyptus-water-garden-in-vase-20.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124232376/aloe-plant-with-cement-planter-36.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124222852/greenery-arrangement-with-gold-wire-frame-6.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124354019/variegated-greenery-in-metallic-pot-10.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124232376/aloe-plant-with-cement-planter-36.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124313872/eucalyptus-plant-with-white-planter-11.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124390000/cherry-leaves-pick-12.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124343030/pink-butterfly-spray-18.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/125000419/variegated-monstera-leaf-38.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124342703/eucalyptus-stem-35.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124411725/variegated-pittosporum-pick-10.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/124377094/grass-pick-12.jpg',
#  'https://static.athome.com/images/w_1000,h_1000,c_pad,f_auto,fl_lossy,q_auto/p/125000346/ficus-spray-green-pick-14.jpg',
#  'https://source.widen.net/content/kkabkknunb/webp/BLU-W_Classic-Blue-Spruce-Wreath-Set-of-2_26in-LEDCL_SSC-10.webp',
#  'https://source.widen.net/content/544i5xllsy/webp/4001371_Adjustable-Metal-Wreath-Hanger_SSC-10.webp',
#  'https://source.widen.net/content/hn4zmrbfga/webp/STG-1441003_Double-Wreath-Storage-Bag_SSC-40.webp',
#  'https://source.widen.net/content/zecc8tyvrr/webp/CDL-2411000_Brass-Antiqued-Metal-Lantern_30in_Lifestyle-10.webp',
#  'https://source.widen.net/content/uegasgec7v/webp/STG-1741001_Rolling-Multipurpose-Storage-Box_SSC.webp',
#  'https://source.widen.net/content/ukbuxxtmrg/webp/URN-2211000_Gray-Sculpted-Planter_16in-Diameter_SSC.webp',
#  'https://source.widen.net/content/awfpck3tik/webp/CDL-1641012_Scents-of-the-Season-Fragrance-Machine_Lifestyle-10.webp',
#  'https://source.widen.net/content/bmvnuivviq/webp/CDL-2411001_8in-Outdoor-Miracle-Flame-LED-Pillar-Candle_SSC.webp',
#  'https://source.widen.net/content/fwpx0myujh/webp/WRG-2341012_Cedar-Woods-Wreath_SSCR.webp',
#  'https://source.widen.net/content/jukjbavlbj/webp/BFR-W_BH-Balsam-Fir-Garland_10ft-Clear_SSC-50.webp',
#  'https://source.widen.net/content/ryyztor0sr/webp/FRR-W_BH-Fraser-Fir-Garland_6ft-LEDCL_SSC.webp',
#  'https://source.widen.net/content/r0xjfrm7pg/webp/STG-1441003_Wreath-Storage-Bag_SSC-10.webp',
#  'https://source.widen.net/content/x5qyv5dfxr/webp/URN-2211001_Taupe-Fluted-Planter-16in-Diameter_SSC.webp',
#  'https://source.widen.net/content/8vnptok2sw/webp/WRG-2141021_Outdoor-Finial-Boxwood-Topiary_14in_SSC.webp',
#  'https://source.widen.net/content/ffhjl5etbv/webp/BER-W_Berkshire-Mountain-Fir-Garland_10ft-Clear_SSC-50.webp',
#  'https://source.widen.net/content/psingtiwwh/webp/OUT-2341015_Outdoor-Cascade-Tree-Light-String_SSC.webp',
#  'https://source.widen.net/content/chgip07ct8/webp/WRG-2341012-2_Cedar-Woods-Garland_SSC.webp',
#  'https://source.widen.net/content/ygxm0c5cgr/webp/WRG-2241018_Fresh-Noble-Fir-Woodland-Garland_10ft_Unlit_SSC.webp',
#  'https://source.widen.net/content/jnkeqry32h/webp/VWS-W_Vermont-White-Spruce-Wreath_26in-LEDCL_SSCR.webp',
#  'https://source.widen.net/content/wjg2rvwk0m/webp/BLU-W-1_10ft-Classic-Blue-Spruce-Garland_SSC.webp',
#  'https://source.widen.net/content/rjma1iqxht/webp/BFR-W_BH-Balsam-Fir_26in-LEDCL_SSCR.webp',
#  'https://source.widen.net/content/eciodhnd6w/webp/WRG-2441026_10ft-Fresh-Wispy-Cedar-Garland_SSC.webp',
#  'https://source.widen.net/content/yhgaywkclr/webp/VWS-W_Vermont-White-Spruce-Garland_10ft-Clear_SSC.webp',
#  'https://source.widen.net/content/sdh5bnpld7/webp/CDL-21410021_Outdoor-Cascading-Micro-LED-Lights_Lifestyle-10.webp',
#  'https://source.widen.net/content/6nylujxeuj/webp/FRR-W_BH-Fraser-Fir-Wreath_26in-LEDCL_SSCR.webp',
#  'https://source.widen.net/content/ljjyyyzyqb/webp/BER-W_22in-Double-Sided-Berkshire-Mountain-Wreath_LEDCL_SSCR.webp',
#  'https://source.widen.net/content/svebj31vgs/webp/WRG-2141021_Outdoor-Double-Ball-Boxwood-Topiary_14in_SSC.webp',
#  'https://serenespacesliving.com/cdn/shop/files/SSLKZ9571511SFS_5.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSLES60133PACK125.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSLYMNSTL18075SFS_5.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSL24240018SFS4.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSL23220017SFS4.jpg',
#  'https://serenespacesliving.com/cdn/shop/products/SSL1001GHY40SFS_6_5cfb9ba9-02e1-4b46-b7a6-253c69205c4a.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSLTG641433B40SFS_4.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSLGB259RSFS6.jpg',
#  'https://serenespacesliving.com/cdn/shop/products/SSLCH06717579SFS2.jpg',
#  'https://serenespacesliving.com/cdn/shop/products/SSL1001GHYMSFS_3.jpg',
#  'https://serenespacesliving.com/cdn/shop/products/faceted-crystal-bud-vase-small2-cv085s_mag_view.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSLYM1555PACK125.jpg',
#  'https://serenespacesliving.com/cdn/shop/files/SSL24260011SFS4.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHD258-GRTP_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHD286-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHD454-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4262-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4261-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4258-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/XP10003-MI_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/PG4200-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/WHD250-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/PG3124-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/SDP578-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/XP030008-GRBR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/P9502-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/P9531-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/P9531-VGGR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/XP20073-YL_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4251-GRGY_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WDP741-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHXDP060-GR_1800x1800.JPG',
#  'https://www.winwardhome.com/cdn/shop/products/XP065019-GRBR_8eeba3cf-b751-4bb2-9c62-8adc5a7f15cb_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHPG3135-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/XP085056-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHD118-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4095-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/XDP052-GRBR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4096-GR-front_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/P4094-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/files/P4097W-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/XP062230-GR_1800x1800.jpg',
#  'https://www.winwardhome.com/cdn/shop/products/WHPG3133-GR_1800x1800.jpg']

# %% [markdown]
# #### quick view

# %%
flowers = df[df.plant_type == 'flower']
flowers = df[df.how_many_flowers > 0]
arrangements = flowers[flowers.product_type == 'arrangement']
single_stems = flowers[flowers.product_type == 'single stem']

pd.DataFrame(flowers.product_type.value_counts(normalize = True)).round(2)
# Out:
#               proportion
# product_type
# arrangement         0.68
# single stem         0.29
# wreath              0.02
# other               0.01
# garland             0.00
# flowerhead          0.00
# teardrop            0.00

# %% [markdown]
# #### One flower vs. multiple flowers

# %%
pd.DataFrame(flowers.how_many_flowers.value_counts(normalize = True)).round(2)
# Out:
#                   proportion
# how_many_flowers
# 1                       0.83
# 2                       0.09
# 3                       0.06
# 4                       0.03
# 5                       0.00
# 6                       0.00
# 7                       0.00

# %% [markdown]
# ### DF collection
#
# - Keyword usage needs to be consistent and professional. Best achieved if we provide a standard list of possible choices. Otherwise, it will be all over the place. For instance, GPT might call 1 style 2 different words...Definition of each word needs to be very clear.
# - Need to make sure keywords aren't being used randomly...(might want to remove text generation...). Maybe use text generation ONLY for the material.
# -

# %%
def filter_rows_by_keywords(df, col, searchwords):
    if not isinstance(searchwords, (list, tuple)):
        raise ValueError("searchwords must be a list or tuple of strings.")

    mask = df[col].apply(lambda lst: all(word in lst for word in searchwords))
    return df[mask]

# %%
# rustic = filter_rows_by_keywords(df, "style", ['rustic'])

# %% [markdown]
# #### Flower type

# %%
counts, pcts, color_table = df_to_colortable(df, "flower_type")
color_table
# Out:
# store_sizes [327, 18, 115, 53, 218, 351, 185, 79, 189, 116, 249, 616, 88, 166, 118, 141, 52, 90, 340]
# Index(['Aflora', 'At Home', 'Balsam Hill', 'Bloomist', 'Diane James Home',
#        'Distinctive Designs', 'Emilio Robba', 'Faux Flower Company',
#        'Flowerbx', 'Horchow', 'Nearly Natural', 'New Growth Designs',
#        'Perigold', 'Pottery Barn', 'Prestige Botanicals', 'Real Touch Flowers',
#        'Serene Spaces', 'Stilla', 'Winward'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_94794_row0_col0, #T_94794_row0_col18, #T_94794_row1_col18 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_94794_row0_col1, #T_94794_row0_col8, #T_94794_row2_col1, #T_94794_row2_col3, #T_94794_row3_col1, #T_94794_row3_col6, #T_94794_row3_col8, #T_94794_row4_col1, #T_94794_row4_col3, #T_94794_row4_col6, #T_94794_row4_col8, #T_94794_row5_col1, #T_94794_row5_col3, #T_94794_row5_col6, #T_94794_row5_col16, #T_94794_row5_col17, #T_94794_row6_col1, #T_94794_row6_col3, #T_94794_row6_col6, #T_94794_row6_col7, #T_94794_row6_col8, #T_94794_row6_col15, #T_94794_row6_col16, #T_94794_row7_col1, #T_94794_row7_col8, #T_94794_row7_col15, #T_94794_row7_col16, #T_94794_row7_col17, #T_94794_row8_col0, #T_94794_row8_col1, #T_94794_row8_col2, #T_94794_row8_col3, #T_94794_row8_col4, #T_94794_row8_col13, #T_94794_row8_col14, #T_94794_row8_col16, #T_94794_row9_col1, #T_94794_row9_col6, #T_94794_row9_col8, #T_94794_row9_col9, #T_94794_row9_col14, #T_94794_row9_col17, #T_94794_row10_col0, #T_94794_row10_col1, #T_94794_row10_col6, #T_94794_row10_col9, #T_94794_row10_col11, #T_94794_row10_col12, #T_94794_row10_col14, #T_94794_row10_col15, #T_94794_row10_col16, #T_94794_row10_col18, #T_94794_row11_col2, #T_94794_row11_col3, #T_94794_row11_col7, #T_94794_row11_col12, #T_94794_row11_col13, #T_94794_row11_col17, #T_94794_row12_col1, #T_94794_row12_col3, #T_94794_row12_col5, #T_94794_row12_col6, #T_94794_row12_col7, #T_94794_row12_col8, #T_94794_row12_col10, #T_94794_row12_col13, #T_94794_row12_col15, #T_94794_row12_col16, #T_94794_row12_col17, #T_94794_row13_col1, #T_94794_row13_col3, #T_94794_row13_col13, #T_94794_row13_col14, #T_94794_row13_col16, #T_94794_row13_col17, #T_94794_row14_col1, #T_94794_row14_col5, #T_94794_row14_col6, #T_94794_row14_col7, #T_94794_row14_col8, #T_94794_row14_col11, #T_94794_row14_col12, #T_94794_row14_col16, #T_94794_row14_col17, #T_94794_row14_col18, #T_94794_row15_col0, #T_94794_row15_col1, #T_94794_row15_col3, #T_94794_row15_col4, #T_94794_row15_col6, #T_94794_
#  'bird of paradise',
#  'gardenia',
#  'lily of the valley',
#  "baby's breath",
#  'lisianthus',
#  'camellia',
#  'dogwood',
#  'petunia',
#  'bromeliad',
#  'heliconia',
#  'waxflower',
#  'freesia',
#  'grape hyacinth',
#  'pincushion protea',
#  'forsythia',
#  'cosmos',
#  'bells of ireland',
#  'hibiscus',
#  'amaranthus',
#  'yarrow',
#  'succulent',
#  'helleborus',
#  'mimosa',
#  'astilbe',
#  'flower',
#  'primrose',
#  'tuberose',
#  'agapanthus',
#  'cornflower',
#  'gerbera',
#  'stock',
#  'wisteria',
#  'artichoke',
#  'azalea',
#  'scabiosa',
#  'african violet',
#  "queen anne's lace",
#  'roses',
#  'gloriosa lily',
#  'kalanchoe',
#  'cyclamen',
#  'marigold',
#  'pussy willow',
#  'salvia',
#  'thistle',
#  'violet',
#  'water lily',
#  'billy balls',
#  'cockscomb',
#  'craspedia',
#  'foxglove',
#  'kangaroo paw',
#  'ornamental cabbage',
#  'unknown',
#  'aloe',
#  'alstroemeria',
#  'artichoke flower',
#  'banksia',
#  'begonia',
#  'bell of ireland',
#  'bellflower',
#  'billy buttons',
#  'blossom',
#  'california poppy',
#  'campanula',
#  'clematis',
#  'crocus',
#  'dianthus',
#  'eucalyptus',
#  'forget me not',
#  'fountain grass',
#  'fritillaria',
#  'gerbera daisy',
#  'ginger',
#  'gypsophila',
#  'millet',
#  'other',
#  'peace lily',
#  'phlox',
#  'plumeria',
#  'pompom flower',
#  'statice',
#  'strawberry flower',
#  'veronica',
#  'wildflower']

# %%
counts, pcts, color_table = df_to_colortable(df, "flowers_in_name")
color_table
# Out:
# store_sizes [327, 18, 115, 53, 218, 351, 185, 79, 189, 116, 249, 616, 88, 166, 118, 141, 52, 90, 340]
# Index(['Aflora', 'At Home', 'Balsam Hill', 'Bloomist', 'Diane James Home',
#        'Distinctive Designs', 'Emilio Robba', 'Faux Flower Company',
#        'Flowerbx', 'Horchow', 'Nearly Natural', 'New Growth Designs',
#        'Perigold', 'Pottery Barn', 'Prestige Botanicals', 'Real Touch Flowers',
#        'Serene Spaces', 'Stilla', 'Winward'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_7e8b2_row0_col0, #T_7e8b2_row1_col9, #T_7e8b2_row2_col16 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_7e8b2_row0_col1, #T_7e8b2_row1_col3, #T_7e8b2_row2_col0, #T_7e8b2_row3_col1, #T_7e8b2_row4_col16, #T_7e8b2_row5_col1, #T_7e8b2_row6_col12, #T_7e8b2_row8_col1, #T_7e8b2_row8_col5, #T_7e8b2_row21_col3, #T_7e8b2_row23_col1, #T_7e8b2_row26_col1, #T_7e8b2_row30_col1, #T_7e8b2_row30_col19, #T_7e8b2_row31_col19, #T_7e8b2_row41_col1, #T_7e8b2_row44_col1, #T_7e8b2_row48_col1, #T_7e8b2_row49_col3, #T_7e8b2_row57_col1, #T_7e8b2_row60_col1 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_7e8b2_row0_col2, #T_7e8b2_row1_col12, #T_7e8b2_row2_col15, #T_7e8b2_row3_col9, #T_7e8b2_row5_col15, #T_7e8b2_row6_col18, #T_7e8b2_row16_col6, #T_7e8b2_row20_col19, #T_7e8b2_row21_col19 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T
8b2_row20_col9, #T_7e8b2_row20_col11, #T_7e8b2_row20_col12, #T_7e8b2_row20_col15, #T_7e8b2_row20_col16, #T_7e8b2_row20_col17, #T_7e8b2_row20_col18, #T_7e8b2_row21_col0, #T_7e8b2_row21_col1, #T_7e8b2_row21_col2, #T_7e8b2_row21_col4, #T_7e8b2_row21_col5, #T_7e8b2_row21_col6, #T_7e8b2_row21_col7, #T_7e8b2_row21_col8, #T_7e8b2_row21_col11, #T_7e8b2_row21

# %% [markdown]
# #### Flower combinations
#
# 1. Filter all rows where there's more than 1 flower
# 2. Look at the flowers!

# %%
multiple_flowers = flowers[flowers.how_many_flowers > 1]

# %%
counts, pcts, color_table = df_to_colortable(multiple_flowers, "flower_type", join_keywords = True)
color_table
# Out:
# store_sizes [2, 49, 86, 99, 10, 10, 4, 32, 34, 29, 10, 22, 1, 67, 60]
# Index(['Aflora', 'Balsam Hill', 'Diane James Home', 'Distinctive Designs',
#        'Emilio Robba', 'Faux Flower Company', 'Flowerbx', 'Horchow',
#        'Nearly Natural', 'New Growth Designs', 'Perigold', 'Pottery Barn',
#        'Serene Spaces', 'Stilla', 'Winward'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_5cf47_row0_col0, #T_5cf47_row0_col1, #T_5cf47_row0_col3, #T_5cf47_row0_col4, #T_5cf47_row0_col5, #T_5cf47_row0_col6, #T_5cf47_row0_col8, #T_5cf47_row0_col9, #T_5cf47_row0_col10, #T_5cf47_row1_col0, #T_5cf47_row1_col4, #T_5cf47_row1_col6, #T_5cf47_row1_col9, #T_5cf47_row1_col12, #T_5cf47_row2_col1, #T_5cf47_row2_col4, #T_5cf47_row2_col5, #T_5cf47_row2_col6, #T_5cf47_row2_col7, #T_5cf47_row2_col8, #T_5cf47_row2_col9, #T_5cf47_row2_col10, #T_5cf47_row2_col12, #T_5cf47_row3_col1, #T_5cf47_row3_col4, #T_5cf47_row3_col5, #T_5cf47_row3_col6, #T_5cf47_row3_col7, #T_5cf47_row3_col9, #T_5cf47_row3_col10, #T_5cf47_row3_col11, #T_5cf47_row3_col12, #T_5cf47_row4_col0, #T_5cf47_row4_col1, #T_5cf47_row4_col2, #T_5cf47_row4_col5, #T_5cf47_row4_col6, #T_5cf47_row4_col8, #T_5cf47_row4_col10, #T_5cf47_row4_col11, #T_5cf47_row4_col12, #T_5cf47_row5_col0, #T_5cf47_row5_col1, #T_5cf47_row5_col4, #T_5cf47_row5_col6, #T_5cf47_row5_col8, #T_5cf47_row5_col10, #T_5cf47_row5_col11, #T_5cf47_row5_col12, #T_5cf47_row5_col13, #T_5cf47_row6_col0, #T_5cf47_row6_col1, #T_5cf47_row6_col4, #T_5cf47_row6_col5, #T_5cf47_row6_col6, #T_5cf47_row6_col8, #T_5cf47_row6_col9, #T_5cf47_row6_col11, #T_5cf47_row6_col12, #T_5cf47_row6_col14, #T_5cf47_row7_col0, #T_5cf47_row7_col4, #T_5cf47_row7_col5, #T_5cf47_row7_col7, #T_5cf47_row7_col8, #T_5cf47_row7_col9, #T
#T_5cf47_row16_col10, #T_5cf47_row16_col12, #T_5cf47_row16_col13, #T_5cf47_row16_col14, #T_5cf47_row17_col0, #T_5cf47_row17_col1, #T_5cf47_row17_col5, #T_5cf47_row17_col6, #T_5cf47_row17_col7, #T_5cf47_row17_col8, #T_5cf47_row17_col9, #T_5cf47_row17_col10, #T_5cf47_row17_col11, #T_5cf47_row17_col12, #T_5cf47_row17_col14, #T_5cf47_row18_col0, #T_ ...

# %% [markdown]
# #### Container

# %%
container_counts = pd.DataFrame(arrangements.container.value_counts(normalize = True).round(2))
container_counts
# Out:
#            proportion
# container
# vase             0.70
# pot              0.21
# planter          0.07
# none             0.01
# basket           0.01
# other            0.00

# %% [markdown]
# #### Product type
#
# Single stem vs arrangement

# %%
counts, pcts, color_table = df_to_colortable(df, "product_type")
color_table
# Out:
# store_sizes [327, 18, 115, 53, 218, 351, 185, 79, 189, 116, 249, 616, 166, 118, 141, 52, 90]
# Index(['Aflora', 'At Home', 'Balsam Hill', 'Bloomist', 'Diane James Home',
#        'Distinctive Designs', 'Emilio Robba', 'Faux Flower Company',
#        'Flowerbx', 'Horchow', 'Nearly Natural', 'New Growth Designs',
#        'Pottery Barn', 'Prestige Botanicals', 'Real Touch Flowers',
#        'Serene Spaces', 'Stilla'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_4dc66_row0_col0, #T_4dc66_row3_col17 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_4dc66_row0_col1 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_4dc66_row0_col2 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_4dc66_row0_col3 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_4dc66_row0_col4, #T_4dc66_row0_col9, #T_4dc66_row1_col0, #T_4dc66_row1_col14 {
#   background-color: #60ba6c;
#   color: #f1f1f1;
# }
# #T_4dc66_row0_col5, #T_4dc66_row0_col6 {
#   background-color: #4db163;
#   color: #f1f1f1;
# }
# #T_4dc66_row0_col7 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_4dc66_row0_col8, #T_4dc66_row2_col18 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_4dc66_row0_col10, #T_4dc66_row1_col18 {
#   background-color: #78c679;
#   color: #000000;
# }
# #T_4dc66_row0_col11, #T_4dc66_row1_col11 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_4dc66_row0_col12 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_4dc66_row0_col13, #T_4dc66_row1_col2, #T_4dc66_row2_col0, #T_4dc66_row2_col7, #T_4dc66_row2_col10, #T_4dc66_row2_col15, #T_4dc66_row3_col0, #T_4dc66_row4_col0, #T_4dc66_row4_col3, #T_4dc66_row4_col7, #T_4dc66_row4_col11, #T_4dc66_row6_col2 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_4dc66_row0_col14, #T_4dc66_row1_col15 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_4dc66_row0_col15 {
#   background-color: #7dc87e;
#   color: #000000;
# }
# #T_4dc66_row0_col16, #T_4dc66_row0_col17, #T_4dc66_row0_col18 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_4dc66_row1_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_4dc66_row1_col3 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_4dc66_row1_col4 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T
#       <th id="T_4dc66_level0_col6" class="col_heading level0 col6" >Emilio Robba</th>
#       <th id="T_4dc66_level0_col7" class="col_heading level0 col7" >Faux Flower Company</th>
#       <th id="T_4dc66_level0_col8" class="col_heading level0 col8" >Flowerbx</th>
#       <th id="T_4dc66_level0_col9" class="col_heading level0 col9" >Horchow</th>
#       <th id="T_4dc66_level0_col10" class="col_heading level0 col10" >Nearly Natural</th>
#       <th id="T_4dc66_level0_col11" class="col_heading level0 col11" >New Growth Designs</th>
#       <th id="T_4dc66_level0_col12" class="col_heading level0 col12" >Pottery Barn</th>
#       <th id="T_4dc66_level0_col13" class="col_heading level0 col13" >Prestige Botanicals</th>
#       <th id="T_4dc66_level0_col14" class="col_heading level0 col14" >Real Touch Flowers</th>
#       <th id="T_4dc66_level0_col15" class="col_heading level0 col15" >Serene Spaces</th>
#       <th id="T_4dc66_level0_col16" class="col_heading level0 col16" >Stilla</th>
#       <th id="T_4dc66_level0_col17" class="col_heading level0 col17" >score</th>
#       <th id="T_4dc66_level0_col18" class="col_heading level0 col18" >pct_stores</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >keyword</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4dc66_level0_row0" class="row_heading level0 row0" >arrangement</th>
#       <td id="T_4dc66_row0_col0" class="data row0 col0" >4%</td>
#       <td id="T_4dc66_row0_col1" class="data row0 col1" >44%</td>
#       <td id="T_4dc66_row0_col2" class="data row0 col2" >37%</td>
#       <td id="T_4dc66_row0_col3" class="data row0 col3" >17%</td>
#       <td id="T_4dc66_row0_col4" class="data row0 col4" >92%</td>
#       <td id="T_4dc66_row0_col5" class="data row0 col5" >99%</td>
#       <td id="T_4dc66_row0_col6" class="data row0 col6" >99%</td>
#       <td id="T_4dc66_row0_col7" class="data row0 col7" >97%</td>
#       <td id="T_4dc66_row0_col8" class="data row0 col8" >53%</td>
#       <td id="T_4dc66_row0_col9" class="data row0 col9"

# %%
product_type_distribution = pd.DataFrame(df.product_type.value_counts(normalize = True).round(2))
product_type_distribution
# Out:
#               proportion
# product_type
# arrangement         0.64
# single stem         0.29
# wreath              0.03
# other               0.02
# garland             0.01
#                     0.00
# flowerhead          0.00
# teardrop            0.00

# %% [markdown]
# #### Colors

# %%
counts, pcts, color_table = df_to_colortable(df, "flower_colors")
color_table
# Out:
# store_sizes [327, 18, 115, 53, 218, 351, 185, 79, 189, 116, 249, 616, 88, 166, 118, 141, 52, 90, 340]
# Index(['Aflora', 'At Home', 'Balsam Hill', 'Bloomist', 'Diane James Home',
#        'Distinctive Designs', 'Emilio Robba', 'Faux Flower Company',
#        'Flowerbx', 'Horchow', 'Nearly Natural', 'New Growth Designs',
#        'Perigold', 'Pottery Barn', 'Prestige Botanicals', 'Real Touch Flowers',
#        'Serene Spaces', 'Stilla', 'Winward'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_f0f69_row0_col0, #T_f0f69_row0_col11, #T_f0f69_row1_col15 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T
f69_row17_col5, #T_f0f69_row17_col6, #T_f0f69_row17_col7, #T_f0f69_row17_col8, #T_f0f69_row17_col10, #T_f0f69_row17_col11, #T_f0f69_row17_col12, #T_f0f69_row17_col13, #T_f0f69_row17_col14, #T_f0f69_row17_col15, #T_f0f69_row17_col16, #T_f0f69_row17_col17, #T_f0f69_row17_col18, #T_f0f69_row17_col19, #T_f0f69_row18_col0, #T_f0f69_row18_col1, #T_f0f69_row18_col2, #T_f0f69_row18_col3, #T_f0f69_row18_col4, #T_f0f69_row18_col6, #T_f0f69_row18_col7, #T_f0f69_row18_col8, #T_f0f69_row18_col9, #T_f0f69_row18_col10, #T_f0f69_row18_col11, #T_f0f69_row18_col12, #T_f0f69_row18_col13, #T_f0f69_row18_col14, #T_f0f69_row18_col15, #T_f0f69_row18_col16, #T_f0f69_row18_col18, #T_f0f69_row18_col19, #T_f0f69_row19_col0, #T_f0f69_row19_col1, #T_f0f69_row19_col2, #T_f0f69_row19_col3, #T_f0f69_row19_col4, #T_f0f69_row19_col5, #T_f0f69_row19_col6, #T_f0f69_row19_col8, #T_f0f69_row19_col9, #T_f0f69_row19_col10, #T_f0f69_row19_col11, #T_f0f69_row19_col12, #T_f0f69_row19_col13, #T_f0f69_row19_col14, #T_f0f69_row19_col15, #T_f0f69_row19_col16, #T_f0f69_row19_col17, #T_f0f69_row19_col18, #T_f0f69_row19_col19, #T_f0f69_row20_col0, #T_f0f69_row20_col1, #T_f0f69_row20_col2, #T_f0f69_row20_col3, #T_f0f69_ ...

# %%
# counts, pcts, color_table = df_to_colortable(df, "flower_colors", join_keywords = True)
# color_table

# %%
counts.index.values.tolist()
# Out:
# ['white',
#  'pink',
#  'yellow',
#  'red',
#  'green',
#  'purple',
#  'orange',
#  'cream',
#  'blue',
#  'peach',
#  'light green',
#  'light blue',
#  'light pink',
#  'magenta',
#  'brown',
#  'light purple',
#  'coral',
#  'dark red',
#  'tan',
#  'pale pink',
#  'beige',
#  'dark pink',
#  'pale yellow',
#  'gold',
#  'bright pink',
#  'burgundy',
#  'dark purple',
#  'grey',
#  'lavender',
#  'violet']

# %% [markdown]
# #### Flower combination

# %%
def filter_rows_by_all_keywords(df, col, keywords, all_keywords = False):
    if not keywords or len(keywords) == 0:
        return df
    
    def contains_all_keywords(cell):
        # Handle NaN or None
        if cell is None:
            return False

        # Handle numpy arrays, lists, tuples, sets uniformly
        if isinstance(cell, (np.ndarray, list, tuple, set)):
            cell_iterable = cell
        else:
            # Try to detect NaN scalars
            if pd.isna(cell):
                return False
            cell_iterable = [cell]

        # Lowercase all items for case-insensitive comparison
        cell_strs = [str(item).lower() for item in cell_iterable]

        # Check if every keyword appears in any of the cell strings
        if all_keywords:
            return all(
                any(keyword.lower() in s for s in cell_strs)
                for keyword in keywords
            )
        else:
            return any(
                any(keyword.lower() in s for s in cell_strs)
                for keyword in keywords
            )

    mask = df[col].apply(contains_all_keywords)
    return df[mask]

# %%
hydrangea = filter_rows_by_all_keywords(flowers, 'flower_type', ['hydrangea'])

# %%
counts, pcts, color_table = df_to_colortable(hydrangea, "flower_type")
color_table
# Out:
# store_sizes [58, 26, 8, 58, 99, 9, 18, 1, 34, 54, 74, 13, 31, 16, 29, 1, 46, 62]
# Index(['Aflora', 'Balsam Hill', 'Bloomist', 'Diane James Home',
#        'Distinctive Designs', 'Emilio Robba', 'Faux Flower Company',
#        'Flowerbx', 'Horchow', 'Nearly Natural', 'New Growth Designs',
#        'Perigold', 'Pottery Barn', 'Prestige Botanicals', 'Real Touch Flowers',
#        'Serene Spaces', 'Stilla', 'Winward'],
#       dtype='object', name='store_name')
# <style type="text/css">
# #T_4462f_row0_col0, #T_4462f_row0_col1, #T_4462f_row0_col2, #T_4462f_row0_col3, #T_4462f_row0_col4, #T_4462f_row0_col5, #T_4462f_row0_col6, #T_4462f_row0_col7, #T_4462f_row0_col8, #T_4462f_row0_col9, #T_4462f_row0_col10, #T_4462f_row0_col11, #T_4462f_row0_col12, #T_4462f_row0_col13, #T_4462f_row0_col14, #T_4462f_row0_col15, #T_4462f_row0_col16, #T_4462f_row0_col17, #T_4462f_row0_col18, #T_4462f_row0_col19 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_4462f_row1_col0, #T_4462f_row1_col2, #T_4462f_row1_col7, #T_4462f_row1_col10, #T_4462f_row1_col13, #T_4462f_row1_col14, #T_4462f_row1_col15, #T_4462f_row2_col0, #T_4462f_row2_col2, #T_4462f_row2_col5, #T_4462f_row2_col7, #T_4462f_row2_col12, #T_4462f_row2_col13, #T_4462f_row2_col14, #T_4462f_row2_col15, #T_4462f_row3_col0, #T_4462f_row3_col2, #T_4462f_row3_col6, #T_4462f_row3_col7, #T_4462f_row3_col9, #T_4462f_row3_col12, #T_4462f_row3_col13, #T_4462f_row3_col14, #T_4462f_row3_col15, #T_4462f_row4_col2, #T_4462f_row4_col5, #T_4462f_row4_col6, #T_4462f_row4_col7, #T_4462f_row4_col13, #T_4462f_row4_col14, #T_4462f_row4_col15, #T_4462f_row5_col0, #T_4462f_row5_col2, #T_4462f_row5_col5, #T_4462f_row5_col6, #T_4462f_row5_col7, #T_4462f_row5_col10, #T_4462f_row5_col11, #T_4462f_row5_col13, #T_4462f_row5_col14, #T_4462f_row5_col15, #T_4462f_row6_col0, #T_4462f_row6_col2, #T_4462f_row6_col5, #T_4462f_row6_col7, #T_4462f_row6_col9, #T_4462f_row6_col12, #T_4462f_row6_col13, #T_4462f_row6_col14, #T_4462f_row6_col15, #T_4462f_row6_col16, #T_4462f_row7_col0, #T_4462f_row7_col1, #T_4462f_row7_col2, #T_4462f_row7_col6, #T_4462f_row7_col7, #T_4462f_row7_col11, #T_4462f_row7_col12, #T_4462f_row7_col13, #T_4462f_row7_col14, #T_4462f_row7_col15, #T_4462f_row7_col16, #T_4462f_row8_col0, #T_4462f_row8_col1, #T_4462f_row8_col2, #T_4462f_row8_col6, #T_4462f_row8_col7, #T_4462f_row8_col10, #T_4462f_row8_col11, #T_4462f_row8_col12, #T_4462f_row8_col13, #T_4462f_row8_col14, #T_4